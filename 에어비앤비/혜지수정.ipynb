# %% [markdown]
# # 2. 데이터 준비
# ## 에어비앤비 사용후 만족도 설문조사 데이터
# ### 주변 에어비앤비 실사용자 고객들 대상으로 한 설문조사 데이터이다.
#
# - 타겟 데이터(airbnb.target)
#     1. 에어비앤비 사용 만족도
#
# - 특징 데이터(airbnb.data)
#     1. 체크인시간
#     2. 의사소통
#     3. 청결도
#     4. 위치
#     5. 가격
#     6. 호스트별점(슈퍼호스트)
#     7. 후기
#     8. 호스트응답률

# %%
import pandas as pd
import numpy as np

# %%
airbnb=pd.read_csv('airbnbsurvey.csv', encoding='euc-kr')
airbnb
# Out:
#     체크인시간  의사소통  청결도  위치  가격  호스트별점(슈퍼호스트)  후기  호스트응답률  만족도
# 0       3     4    5   4   3             4   5       4    4
# 1       4     2    4   5   4             3   5       5    4
# 2       5     2    4   4   5             3   4       4    5
# 3       4     3    5   5   4             4   5       5    5
# 4       3     3    5   5   3             3   5       2    3
# 5       5     5    5   3   3             4   5       5    4
# 6       3     5    5   5   4             4   5       4    5
# 7       3     4    5   5   4             3   5       4    4
# 8       3     3    4   5   5             4   4       4    3
# 9       4     3    5   5   5             4   3       3    4
# 10      4     3    5   5   5             4   5       4    5
# 11      4     3    3   4   5             4   5       4    4
# 12      3     3    5   5   5             3   4       4    3
# 13      3     4    5   5   5             4   5       3    4
# 14      5     3    4   5   4             4   5       5    3
# 15      3     3    5   5   4             4   5       4    3
# 16      3     3    4   3   5             4   4       5    3
# 17      3     3    4   5   5             4   5       4    4
# 18      3     3    4   5   3             3   5       4    4
# 19      2     2    5   5   5             5   4       4    3
# 20      4     2    4   4   5             5   5       4    3
# 21      3     2    3   3   2             5   5       5    2
# 22      4     4    4   4   4             4   4       4    4
# 23      4     4    5   5   4             3   4       4    4
# 24      5     5    5   5   5             4   5       5    4
# 25      3     4    5   5   5             4   5       3    4
# 26      4     4    5   4   5             3   5       5    4
# 27      3     4    3   3   4             4   5       5    4
# 28      2     4    5   4   5             5   4       5    4
# 29      4     4    5   4   5             4   5       3    4
# 30      4     3    5   4   4             2   5       5    3
# 31      3     2    4   4   5             4   5       4    3
# 32      2     2    5   5   5             2   5       5    2
# 33      2     2    4   4   4             4   5       4    3
# 34      3     3    3   3   3             3   3       3    3
# 35      4     4    4   3   3             4   4       5    4
# 36      5     5    5   5   5             5   5       5    5
# 37      3     3    3   3   3             3   3       3    3
# 38      4     4    4   4   4             4   4       4    4
# 39      4     4    5   3   5             3   2       5    4
# 40      3     3    3   3   3             3   3       3    3
# 41      3     3    3   3   3             3   3       3    3
# 42      3     3    3   3   3             3   3       3    3
# 43      3     3    3   3   3             3   3       3    3
# 44      5     5    5   4   3             4   4       4    4
# 45      5     5    5   5   5             5   5       5    5
# 46      3     3    3   3   3             3   3       3    3
# 47      3     3    3   3   3             3   3       3    3
# 48      4     4    4   4   4             4   4       4    4
# 49      3     4    3   4   3             3   3       3    3
# 50      2     1    2   2   2             2   2       2    1
# 51      3     3    4   4   3             4   3       4    4
# 52      4     4    4   4   5             4   3       4    4
# 53      5     3    5   3   5             3   4       3    3
# 54      3     3    3   3   3             2   3       2    2
# 55      2     2    2   2   2             3   3       3    1
# 56      3     3    3   3   3             3   3       3    2

# %% [markdown]
# ## StatsModels 모듈을 사용한 선형회귀분석

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# 폰트 문제 해결하기
import platform

path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %% [markdown]
# ## StatsModels 모듈을 사용한 선형회귀분석

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms

# %%
import pandas as pd
# 독립변수
X = pd.DataFrame(airbnb, columns = ["체크인시간", "의사소통", "청결도", "위치", "가격", "호스트별점(슈퍼호스트)", "후기", "호스트응답률"])
# 종속변수
Y = pd.DataFrame(airbnb, columns = ["만족도"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-35ccdf6251e7> in <module>()
#       1 import pandas as pd
#       2 # 독립변수
# ----> 3 X = pd.DataFrame(airbnb, columns = ["체크인시간", "의사소통", "청결도", "위치", "가격", "호스트별점(슈퍼호스트)", "후기", "호스트응답률"])
#       4 # 종속변수
#       5 Y = pd.DataFrame(airbnb, columns = ["만족도"])
#
# NameError: name 'airbnb' is not defined

# %%
# 데이터 준비
dfX0 = pd.DataFrame(airbnb, columns = ["체크인시간", "의사소통", "청결도", "위치", "가격", "호스트별점(슈퍼호스트)", "후기", "호스트응답률"]) # 독립변수
dfX = sm.add_constant(dfX0) # 자동으로 상수항을 만들어주지 않기 때문에 사용자가 add_constant 명령으로 상수항을 추가해야 한다.
dfy = pd.DataFrame(airbnb, columns = ["만족도"]) # 종속변수

# %%
# model_airbnb라는 이름으로 OLS 모델 구조화
model_airbnb = sm.OLS(dfy, dfX) # (종속변수, 독립변수)

# OLS 회귀모형 피팅
result_airbnb = model_airbnb.fit()

# 회귀분석 결과 요약
print(result_airbnb.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    만족도   R-squared:                       0.666
# Model:                            OLS   Adj. R-squared:                  0.611
# Method:                 Least Squares   F-statistic:                     11.98
# Date:                Thu, 07 Jun 2018   Prob (F-statistic):           3.36e-09
# Time:                        15:11:57   Log-Likelihood:                -43.649
# No. Observations:                  57   AIC:                             105.3
# Df Residuals:                      48   BIC:                             123.7
# Df Model:                           8
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           -0.9060      0.488     -1.855      0.070      -1.888       0.076
# 체크인시간            0.2623      0.107      2.455      0.018       0.047       0.477
# 의사소통             0.3558      0.107      3.313      0.002       0.140       0.572
# 청결도             -0.0147      0.150     -0.098      0.923      -0.316       0.287
# 위치               0.3073      0.138      2.221      0.031       0.029       0.585
# 가격               0.1101      0.111      0.996      0.324      -0.112       0.332
# 호스트별점(슈퍼호스트)     0.1592      0.119      1.343      0.185      -0.079       0.397
# 후기              -0.0452      0.120     -0.375      0.709      -0.287       0.197
# 호스트응답률           0.0833      0.112      0.746      0.459      -0.141       0.308
# ==============================================================================
# Omnibus:                        1.534   Durbin-Watson:                   1.282
# Prob(Omnibus):                  0.464   Jarque-Bera (JB):                0.801
# Skew:                           0.190   Prob(JB):                        0.670
# Kurtosis:                       3.440   Cond. No.                         71.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
dfy_new = result_airbnb.predict(dfX)

plt.scatter(dfy, dfy_new)
plt.xlabel(u"실제 만족도")
plt.ylabel(u"만족도 예측치")
plt.show()

# %%
import numpy as np
import random
from PIL import Image
from wordcloud import WordCloud, STOPWORDS
from palettable.colorbrewer.qualitative import Dark2_8
from sklearn.feature_extraction.text import CountVectorizer
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return tuple(Dark2_8.colors[random.randint(0,7)])

font = "NanumPen"
font_path = "%s.ttf" % font

icon = "airbnb-logo" 
icon_path = "%s.png" % icon

# %% [markdown]
# # 워드 클라우드(단어구름)

# %%
import numpy as np
import random
from PIL import Image
from wordcloud import WordCloud, STOPWORDS
from palettable.colorbrewer.qualitative import Dark2_8
from sklearn.feature_extraction.text import CountVectorizer
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# color_func 함수, Dark2_8이라는 pallette를 이용하여 색을 만들어냄.
def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return tuple(Dark2_8.colors[random.randint(0,7)])

# 한글 폰트 지정
font = "NanumPen"
font_path = "%s.ttf" % font

# 아이콘 지정
icon = "airbnb-logo" 
icon_path = "%s.png" % icon

# %% [markdown]
# ### 데이터 입력

# %%
# 1. 후기 안좋은 숙소
f = open("badreview.txt", 'r', encoding='euc-kr')
message_of_guests = f.read()
print(message_of_guests)
f.close()
# Out:
# 위치설명과 소통은 아주 잘되었어요. 하지만 화장실과 침대 청결도가 별로였고 다른 모르는 두분이랑 같은 집을 써야하는게 별로 좋지 않았어요
#
#
# Good 처음 오는 사람 누구나 쉽게 이용할 수 있도록 그리고 제가 시간이 좀 늦고 특이사항이 있었는데 그에준비하셔서 미리 쪽지로 안내도 해주셔서 좋았습니다 Bad 환절기라 보일러를 잘 확인해야는데 이 부분은 잘 챙겨주시면 좋을 것 같습니다 그리고 방 사진이 달라서 살짝 놀랐어요 방에도 포샵 기능이?ㅎ
#
#
# 더럽고 좁고 사진빨이에요. 오지 말도록 하세요。
#
#
# 여행 일정에 공백이생겨 적은 가격으로 하루 묵을 목적으로 숙소를 잡았어요. 가격은 저렴해서 좋았지만 솔직히 아쉬움이 많이 남는 숙소였어요. 무엇보다 큰 창에 비해서 너무 작은커튼과 화장실의 냄새는 가장 아쉬웠던 부분인거 같네요.
#
#
# 홍대 주변이라 편의시설이 좋음 보일러를 직접 작동할 수 있어서 춥지 않음(방은 약간 찬바람이 들어옴) 8명이 숙박하기엔 이불/수건 등 제공해주는 물품들이 부족함 전체적으로 이전 사람들이 사용했던 흔적들이 많았음 사전에 연락도 없이 다음날 숙박예정인 외국인들이 짐을 놓겠다고 무작정 들어옴
#
#
# 빔프로젝트있어서 갔는데 유에스비없으면 못써서 꼭 챙겨가시구요. 티비도 없고 휴지도 조금 부족하고 인원많으시면 수건도 부족하실 수도 있어요! 가격대비 나쁘지 않았지만 그래도 저흰 좀 아쉬웠던 것 같아요!
#
#
# 우선 위치면에서는 홍대입구 근처여서 놀다가 들어가기 좋았습니다~ 하지만 위치를 제외하고 숙소의 용도면에서는.. 주방기구에 기본적인 가위 등도 없어서 음식을 해먹기에는 무리같네요ㅎㅎ 이 점 제외하고 이동성 고려하신다 하면 좋은 것 같습니다
#
#
# 호스트분은 정말 친절하시고 연락도 잘 되어서 좋았어요. 원래 예약한 방이 수도공사로 다른 집을 전체로 쓰실수 있게해주셔서 좋았는데, 생각보다 집이 별로였습니다. ㅠㅠ 일단 작은방 창문이 밖에서도 열릴수 있게 되어있어서 불안했고요.. (위치가 어둡고 반지하였습니다;) 비가 와서 그런지 정말 집이 추웠고.. 화장실이 낡고 오래되었다는 느낌을 받았는데 따듯한 물도 안나와서 샤워를 할 수 없었습니다.
# 욕조가 막히거나 흘러 내리지 않을 수 있습니다. 우리는 그것이 고정되어 있거나 지금은 모르지만, 우리에게는 상당히 끔찍한 경험인데, 샤워를하기 위해 오랜 시간을 기다려야합니다. 바디 워시를 제공하지 않았으며 약간의 샴푸를 먹었을뿐 아니라 스스로 살 필요가 있습니다. 우리는 다음 손님 모두가 필요한 모든 것을 확인하고 주인에게 요청해야한다고 상기시켜줍니다. 우리가 가져 왔어. 욕실이 물에 빠지기가 극히 어려우며 샤워는 물을 기다릴 시간이 걸리고 다음 친구는 물을 마실 수 있습니다. (주택 소유자가 문제를 해결하기를 바랍니다.) 체크인 후에는 목욕 우유, 샴푸, 화장지 및 기타 항목을 즉시 확인하는 것이 좋습니다. 그렇지 않으면 즉시 소유자에게 알리십시오. 우리는 수화물을 놓고 즉시 나갔다. 검사가 없었다. 저녁 12 시경에 샤워 젤과 샴푸를 찾지 않아서 스스로 샀다. 나쁜 경험 : 그 기계는 점검을 위해 집에 오기를 원한다. 그 시간은 우리 일기를 만든다. 붙어있어. 오전 11시에는 세탁기를 사용하여 셔츠를 세탁하고 세탁기는 약 30 분이 걸렸으므로 정오에 약 12시에 나갔다. 그러나 주변에서 오전 12시 30 분에 집주인은 집 안의 기계 소리에 대해 불평하는 이웃으로부터 메시지를 받았다. 소유자는 체크인을 원한다고 표시했다. 여행을 중단하고 돌아가서 확인했지만 주인은 그것을 보지 못했다. 우리는 우리 자신의 검사 후에 아무 문제없이 떠났다. 그러나 주인은 밤까지 응답하지 않았습니다. 나중에 나는 저녁에 세탁기를 사용하려고했지만 목소리가 들리지 않았습니다. 정말로 무슨 일이 있었는지 모르겠다. 나는 정말 끔찍하고 정말로 안보였습니다. 각 게스트 후에 암호를 변경하십시오. 흰색 11시 이전에 방을 떠난 날을 확인하십시오. 그러나 1030 년경에 다음 거주자가 실제로 비밀 번호로 집에 들어 왔습니다. 우리는 겁에 질렸다. 그 당시, 우리는 집안에서 옷을 갈아 입고 있었다! 매우 불안합니다. 우리는 또한 소유자가 다음 세입자가 사용하기 전에 암호를 변경한다고 생각했습니다. 체크인 시간이 오후 3시이며 당일 패스워드가 필요하다고 소유자가 알리는 경우 오후 11시 이후에 다음 번 세입자를주지 않으시겠습니까?
#
#
# 욕실의 시설은 조금 오래되었습니다.
#
#
# 체크인 하루 전날 호스트에게서 홍대역에서부터 도보로 숙소를 가는 방법을 사진으로 알려주는 웹사이트를 제공받았습니다. 호스트가 제공한 웹사이트에는 숙소의 주소가 없었습니다. 나는 홍대역에서 숙소로 출발하지 않기에 호스트가 제공한 오는 방법은 쓸모가 없었습니다. 우리일행은 예약시 에어비앤비에서 제공받은 숙소주소로 택시를 타고 갔습니다. 그러나 도착한 곳은 엉뚱한 곳이었습니다. 호스트에게 숙소위치가 잘못되었다고 연락하였으나, 호스트는 본인이 체크인 하루 전날 보내준 웹사이트에 써져 있는 숙소의 주소가 맞는 것이라고 말하며 예약시 제공받은 숙소주소는 틀린 것이고 자기가 보내준 그 사이트를 참고해서 와야 한다고 했습니다. 그러나 호스트가 보내준 웹사이트에는 숙소의 주소가 없었으며 이미 잘못된 주소지에 도착한 우리는 홍대입구에서 도보로 가는 방법만 알려주는 그 웹사이트의 정보로는 숙소를 찾아갈 수 없었습니다. 호스트에게 다시 전화해 그 사이트에 숙소의 주소는 없으니 직접 주소를 알려달라 재차 통화를 한 뒤에 그제서야 우리는 숙소를 찾아갈 수 있었습니다. 여행구성원간의 사전 여행계획 수립을 위해 숙소 가는법 같은 중요한 정보는 체크인 하루 전날에 알려주는게 아니라 빨리 제공해야합니다. 그리고 에어비앤비에 예약페이지에서 제공하는 숙소주소와 실 숙소의 주소가 다르다면 그 사실을 반드시 예약고객에게 알려줘야합니다. 호스트가 하루 전날 제공한 오는 방법에는 숙소의 주소가 나와있지 않기에 더욱 그렇습니다. 홍대역에서 도보로 숙소를 방문하지 않는 우리와 같은 예약고객도 있기 때문입니다. 우리는 에어비앤비에 등록된 숙소주소랑 실 숙소 주소가 다르다는걸 고지받지 못해서 영하 6도의 추운날에 짐 엄청 들고 숙소를 찾아 홍대를 돌아다녔습니다.
#
#
# 위치는 정말 좋았습니다. 다만 침구가 청결하지 못했습니다. 남자 머리카락들이 이불에 잔뜩있았습니다. 또 제가 먼지 알러지가 있는데 정말 힘들었습니다. 치약이 없어서 당황스러웠습니다. 집도 크고 위치도 좋았고 드라이기 2개, 호스트님과의 연락이 빠른점은 좋았습니다.
#
#
# 대응이 너무 늦었어요
#
#
# 다만 아쉬운점은 청소 상태가 아쉬운 부분입니다
#
#
# 전체적인 시설상태가 불량하고, 체크인시 청소가 되어있지 않고, 위생상태가 엉망입니다. 최악이었음 ㅜ.ㅜ
#
#
# 나는이 집의 청결 함에 실망했다. 나는 그것을 해결하기 위해 숙주와 함께 집을 가져왔다. 그러나 나는 결국 불행했다. 나는 Airbnb 집에 대한 나쁜 리뷰를 작성한 적이 없으며, 나는 매우 이해가 쉽다. 그러나이 리뷰는 매우 실망스럽고 화가 나있다. 호스트가 나와 함께 기꺼이 노력한다면 내 경험이 더 좋을 것이라고 생각합니다.
#
#
# 나쁘지 않았어요~ 1박 또는 2박만 이용할거라면 충분한 숙소입니다. 다만 아쉬웠던점은 의자 하나가 고장나 있었고, 세면대 물이 잘 내려가지 않았네요. 하지만 호스트님께서 빠르게 연락을 받아주셔서 괜찮았어요. 그동안 방문했던 다른 숙소들에 비해 비교적 별로였지만 기본적인 것들은 잘 갖춰진 숙소입니다. 좋은점은 언주역에서 6분거리라는점입니다.
#
#
# 가격값하는 곳. 호스트분의 적극적인 피드백이 마음에 들었음. 소음은 다 들려서 밤마다 옆의 커플분 때문에 조금 힘들었어요. 저만 와이파이가 안돼서 핸드폰￡노트북을 못했는데 에그 가지고 와주셔서 잘 썼습니다. 벽지에 모기 시체가 좀 많아서 볼때마다 거부감이 들었어요. 수건은 넉넉하게 많았구요 햇볕이 잘 듭니다. 화장실도 양호한 편이에요. 엘레베이터가 없어서 짐 드는데 조금 힘들었어요. 위치는 조용한곳에 있어서 바깥소음은 잘 안들려서 좋았습니다.
#
#
# 깔끔하고 넓은 숙소에 놀라고, 주차시설이 편해서 좋았습니다. 그리고 연락이 바로바로 원활하게 되어서 편안한 여행이 되었습니다. 다만, 계단은 고려해야합니다~ 많이 힘들진 않아요!
#
#
# 정말오래된집이라 사진처럼 깨끗하고 깔끔한 분위기는 전혀아니에요, 조명도 어둡고 곳곳이 부식됐어요 늦은밤도착해 저렴한 가격에 잠만잔다면 모를까 추천하고 싶진않습니다
#
#
# 식기가 너무 더러워요~ 세제도 없어서 기다리기 귀찮아서 그냥 사다놨어요 ㅋㅋ 그거 외에는 사진이랑 똑같고 깨끗해용 들어가자마자 너무 따듯해서 좋아요!! 침구상태도 다 좋은데 부엌 식기 상태가 좀 ㅎㅎㅋㅋ 그거빼고는 다 완벽해요 ㅋㅋㅋ 그리고 폼클렌징이나 이런거는 다 따로챙겨가는게 좋을거같아요~~!
#
#
# 전반적으로 깨끗한 편이었어요 사진과 달리 수건은 큰거 하나라 두명이서 쓰기 불편했어요 쓰기에 충분은 하지만... 길 찾기 쉽기는 하지만 건물과 건물 사이 틈이라 어두워서 여자끼리 다니긴 무서웠습니다
#
#
# 지하철 신논현역에서 가까우며 공항 버스 이용이 용이한 위치적인 장점, 친절한 호스트분의 안내가 만족스러웠습니다. 반면에 너무 낡은 숙소건물과 청소비용이 따로 청구됨에도 작은 카펫과 바닥에 많던 머리카락과 먼지, 냉장고 코드를 빼두어 냉장고를 열자마자 녹은 물이 흘러나온 점 등 사진에서와 같이 깔끔한 숙소는 아니니 청결도를 가장 우선으로 보시는 게스트분들께는 추천하지 않습니다.
#
#
# 화장실 청소상태나 침대커버에 붙어있는 머리카락들이며...청소비용지불을 해야하는게 맞나 하는 불쾌함이 남는 여행이었습니다
#
#
# 전반적으로 별로입니다. 늦은시간 급하게 저렴한 가격으로 머무실 분들에게 추천합니다. 1. 주차가 안됩니다. 일단 집앞 주차는 못하신다고 보시면 되고, 알려주신 근처 주차공간 역시 선착순일 뿐더러 멉니다. 따라서 이틀 이상 머무시는 경우 하루종일 주차해두기도 어렵습니다. 2. 청소가 불완전합니다. 저는 캐리어를 테이블 아랫쪽에 넣어줬는데, 쓰지 않는 와이파이 공유기 앞뒤양옆으로 먼지가 뭉쳐서 굴러다닙니다. 3. 불친절합니다. 제가 늦게 예약을 했다는 이유로(이것마저도 체크인 전) 8시 반에나 체크인 할 수 있다고 하셨습니다. 물론 7시 반쯤 준비가 다 되었다고 오라고 하시긴 했는데, 날씨가 너무 추웠고 있을만한 공간이 없어서 이미 멀리 나온 상태였습니다. 의사 소통간 오해가 생겨도 굉장히 기분 나쁜투로 대답해주시고요. 이밖에도 화장실이 굉장히 춥다거나, 사진과 숙소 모습이 많이 다른것도 있습니다. 방 난방은 잘되고, 침대는 편안합니다.
#
#
# 수건이 좀 깨끗한거였음 더 좋았을서같아요
#
#
# 신논현역 근처라 지하철로 이동가능해서 편해요. 주변에 슈퍼랑 편의점도 있고 바로 도심이라 괜찮아요. 다만 방이 1층이긴 한데 사실상 반지하라 햇빛도 잘 들지 않고 밤에 들어오면 쿱쿱한 지하 냄새가 나요. 이 점은 숙소 소개에 나와있지 않아서 참고하셔야 해요. 그리고 호스트 분이 굉장히 친절하세요. 하지만 해외에 거주하고 계신지 낮시간에는 연락이 잘 되지 않더라고요.
#
#
# 거리와 리뷰를 보고 첫 에어비앤비 숙소를 여기로 결정했습니다. 사전에 도착시간을 알려드렸고, 당일 체크인하려는데 알려주신 비밀번호가 틀리다고해서 연락, (10분정도 문앞에 서서 기다림) 연락이 늦어지니 초조하고 일정을 위해 움직여야하는데 시간을 낭비했습니다. 혼자 묵기에는 작지도 크지도 않은 방인데 침대 한개 + 바닥 매트리스가 하나 더 깔려있어서 불편했습니다. 바닥과 침대에 머리카락도 한두어개있었고 심지어 작은 유리조각 같은 밟으면 안될뻔한것도 발견, (셀프로 방청소함) 냉장고에는 누가 먹으려했는지 단무지도 있었어요. 욕실은 물이 천천히 빠지는데 욕실이 현관옆이라 슬리퍼가 없으면 발이 더러워져요. 수건은 2개 요청했었는데 한개뿐이라 직접 가질러갔어요(수건 냄새가 퀘퀘함), 전체적인 분위기는 모던하고 깔끔했는데 자세히보니 위생에 문제가 있네요. 첫 에어앤비의 경험이 좋지 않아서 덕분에 신중해질꺼같네요.
#
#
# 더러운 이불
#
#
# 원룸형 오피스텔이었구요, 역에서 가까운 거리, 어느 쪽으로 가도 3분 내로 있는 편의점 및 카페, 강남역/교대역 등 이동 편리한 위치인 게 최고 장점. 하지만 노후된 욕실(칠이 벗겨지거나, 떼탔거나, 깨끗하다고 느껴지진 않음)과 사용은 안했지만 주방과 냉장고 상태도 좋다고는 못하겠네요. 냉장고에는 이전 게스트 것인지, 호스트분 것인지 모를 음식들이 남아있었고 냉동실 칸에는 뭘 넣어도 괜찮은걸까 싶게 흙먼지?같은 게 깔려있었어요. 쓰레기통도 완전히 비지 않은 상태로 휴지같은게 차있었고..해서 위생상태는 아쉽습니다. 그래도 온수 잘 나오고 수압도 괜찮고 머무르기에 크게 불편한점은 없었습니다. 방음은 잘 안되는듯 하고, 일 때문에 서초쪽 들르시는 분한테는 적합한 숙소라고 생각되네요.
#
#
# 하루 묵기 좋다. 다만 인터넷이 안되고 티비가 없다. 침대는 싱글이라서 2명이서 자긴 힘들것같다.
#
#
# 이 지역에서 활동하기에 적당한 위치에 자리잡고 있으나 그 것을 제외하고는 추천할 만한 이유가 전혀 없는 곳 입니다. 1.첫번째 체크인 시간으로부터 4시간 후에 도착했음에도 불구하고 청소가 되지 않아 1시간을 더 기다려야 했습니다. 예정된 체크인 시간보다 5시간 후에 체크를 했습니다. 2. 욕실에서 냄새가 났습니다. 청결도에서 호텔 수준을 바라는건 아니지만,전혀 상쾌하지 않았습니다. 3. 집의 사용에 대한 안내를 전혀 받지 못했습니다. 체크인전 이메일로 연락하면 회신에 시간이 걸립니다.
#
#
# 지하철에서 내려서 조금만 걸으면 됩니다 고시룸 이라 보면 되겠네요 화장실은 딸려 있구요 에어컨이 빵빵해서 추워습니다 그리고 화장실이 샤워하기 좀 좁았습니다
#
#
# 네비따라 갔더니 집은 쉽게 찾을 수 있었어요.체크인 시간이 늦어진 점과 주차공간이 아쉬웠어요. 주차공간이 있다고 생각하고 갔는데, 혼잡한 서울의 교통 상황으로 차를 두고 다니는 동안 불안 불안..
#  친절하게 맞아주신 Mori mom님 감사해요. 깨끗하고 따뜻한 집에서 2박 잘 있다왔습니다.
#
#
# 전반적으로 별로입니다. 늦은시간 급하게 저렴한 가격으로 머무실 분들에게 추천합니다. 1. 주차가 안됩니다. 일단 집앞 주차는 못하신다고 보시면 되고, 알려주신 근처 주차공간 역시 선착순일 뿐더러 멉니다. 따라서 이틀 이상 머무시는 경우 하루종일 주차해두기도 어렵습니다.
#  2. 청소가 불완전합니다. 저는 캐리어를 테이블 아랫쪽에 넣어줬는데, 쓰지 않는 와이파이 공유기 앞뒤양옆으로 먼지가 뭉쳐서 굴러다닙니다.
#  3. 불친절합니다. 제가 늦게 예약을 했다는 이유로(이것마저도 체크인 전) 8시 반에나 체크인 할 수 있다고 하셨습니다. 물론 7시 반쯤 준비가 다 되었다고 오라고 하시긴 했는데, 날씨가 너무 추웠고 있을만한 공간이 없어서 이미 멀리 나온 상태였습니다. 의사 소통간 오해가 생겨도 굉장히 기분 나쁜투로 대답해주시고요.
#
#  이밖에도 화장실이 굉장히 춥다거나, 사진과 숙소 모습이 많이 다른것도 있습니다. 방 난방은 잘되고, 침대는 편안합니다.

# %%
# 후기 안좋은 숙소 전처리
message_of_guests = message_of_guests.split('\n\n')
message_of_guests
# Out:
# ['위치설명과 소통은 아주 잘되었어요. 하지만 화장실과 침대 청결도가 별로였고 다른 모르는 두분이랑 같은 집을 써야하는게 별로 좋지 않았어요',
#  '\nGood 처음 오는 사람 누구나 쉽게 이용할 수 있도록 그리고 제가 시간이 좀 늦고 특이사항이 있었는데 그에준비하셔서 미리 쪽지로 안내도 해주셔서 좋았습니다 Bad 환절기라 보일러를 잘 확인해야는데 이 부분은 잘 챙겨주시면 좋을 것 같습니다 그리고 방 사진이 달라서 살짝 놀랐어요 방에도 포샵 기능이?ㅎ',
#  '\n더럽고 좁고 사진빨이에요. 오지 말도록 하세요。',
#  '\n여행 일정에 공백이생겨 적은 가격으로 하루 묵을 목적으로 숙소를 잡았어요. 가격은 저렴해서 좋았지만 솔직히 아쉬움이 많이 남는 숙소였어요. 무엇보다 큰 창에 비해서 너무 작은커튼과 화장실의 냄새는 가장 아쉬웠던 부분인거 같네요.',
#  '\n홍대 주변이라 편의시설이 좋음 보일러를 직접 작동할 수 있어서 춥지 않음(방은 약간 찬바람이 들어옴) 8명이 숙박하기엔 이불/수건 등 제공해주는 물품들이 부족함 전체적으로 이전 사람들이 사용했던 흔적들이 많았음 사전에 연락도 없이 다음날 숙박예정인 외국인들이 짐을 놓겠다고 무작정 들어옴',
#  '\n빔프로젝트있어서 갔는데 유에스비없으면 못써서 꼭 챙겨가시구요. 티비도 없고 휴지도 조금 부족하고 인원많으시면 수건도 부족하실 수도 있어요! 가격대비 나쁘지 않았지만 그래도 저흰 좀 아쉬웠던 것 같아요!',
#  '\n우선 위치면에서는 홍대입구 근처여서 놀다가 들어가기 좋았습니다~ 하지만 위치를 제외하고 숙소의 용도면에서는.. 주방기구에 기본적인 가위 등도 없어서 음식을 해먹기에는 무리같네요ㅎㅎ 이 점 제외하고 이동성 고려하신다 하면 좋은 것 같습니다',
#  '\n호스트분은 정말 친절하시고 연락도 잘 되어서 좋았어요. 원래 예약한 방이 수도공사로 다른 집을 전체로 쓰실수 있게해주셔서 좋았는데, 생각보다 집이 별로였습니다. ㅠㅠ 일단 작은방 창문이 밖에서도 열릴수 있게 되어있어서 불안했고요.. (위치가 어둡고 반지하였습니다;) 비가 와서 그런지 정말 집이 추웠고.. 화장실이 낡고 오래되었다는 느낌을 받았는데 따듯한 물도 안나와서 샤워를 할 수 없었습니다.',
#  '\n일단 홍대역이랑 너무가깝고 위치설명도 잘해주셔서 한번에 찾았구요! 고양이가 문에서인사해줘서 ㅎㅎ너무 좋았어요 체크인시간도 편하게해주셔서 다른 곳처럼 동동거리지않아도되고 출입도 자유로워서 좋았어요! 아쉬운건 화장실 비품이없어서 아쉬웠어요!',
#  '\n위치 시설 모두 만족스러웠습니다. 다만 냉장고가 고장난 상태였고 그로 인해 악취가 났었습니다.',
#  '\n위치도 너무좋고 너무 편하게 쉬고 가요!! 다만 청소상태가 ㅠㅠ.. 먼지가 조금 많이 보이네요ㅠㅠ 그것 말고는 다 좋았습니다!!',
#  '\n홍대 한복판이라 위치는 아주 좋음. 따뜻한 물도 잘 나오고 수압도 셌음. 방크기도 적절, 보일러도 잘 돌아감 하지만 청소 상태가 몹시 좋지 않았음. 주변 방들보다 다소 저렴한 가격에 예약했지만 그럼에도 불구하고 불쾌할 정도로 지저분했음. 위생 상태를 제외하고는 특별히 불만족스러운 부분은 없음.',
#  '\n따뜻하고 예쁘고 안락한 방이었습니다. 온수가 종종 끊겼지만요ㅠㅠ 칫솔 따로 없고 샴푸린스바디클렌징폼 있어요! 수건 넉넉히 챙겨주셔서 감사합니다 ㅎㅎ 다음에 홍대에 간다면 또 묵고 싶어요!',
#  '\n역이랑 가까웠는데 제가 길을못찾아서 거의 한시간반을 헤맸어요.길치의 탓ㅜ.우선 날이추워서 들어가보니 보일러 외출로 되있어서 온돌로 바꾸고 방데워지는데 2-3시간 걸린것 같아요~그전엔 추워서 덜덜.보일러로 데우고나니 따뜻하더라구요.인터넷잘되구.온수잘나오고.밖에 먹을곳도 많아서 위치좋았습니다.가격대비 굿.추운날 일찍가셔서 방데우고 쓰심 좋을듯해요~^^',
#  '\n위치도 너무 좋고 방도 너무 깔끔했어요. 다만 아쉬운건 티비하고 온수작동이 안된것이고 대체적으로 만족스러웠습니다!',
#  '\n체크인 하루 전날 호스트에게서 홍대역에서부터 도보로 숙소를 가는 방법을 사진으로 알려주는 웹사이트를 제공받았습니다. 호스트가 제공한 웹사이트에는 숙소의 주소가 없었습니다. 나는 홍대역에서 숙소로 출발하지 않기에 호스트가 제공한 오는 방법은 쓸모가 없었습니다. 우리일행은 예약시 에어비앤비에서 제공받은 숙소주소로 택시를 타고 갔습니다. 그러나 도착한 곳은 엉뚱한 곳이었습니다. 호스트에게 숙소위치가 잘못되었다고 연락하였으나, 호스트는 본인이 체크인 하루 전날 보내준 웹사이트에 써져 있는 숙소의 주소가 맞는 것이라고 말하며 예약시 제공받은 숙소주소는 틀린 것이고 자기가 보내준 그 사이트를 참고해서 와야 한다고 했습니다. 그러나 호스트가 보내준 웹사이트에는 숙소의 주소가 없었으며 이미 잘못된 주소지에 도착한 우리는 홍대입구에서 도보로 가는 방법만 알려주는 그 웹사이트의 정보로는 숙소를 찾아갈 수 없었습니다. 호스트에게 다시 전화해 그 사이트에 숙소의 주소는 없으니 직접 주소를 알려달라 재차 통화를 한 뒤에 그제서야 우리는 숙소를 찾아갈 수 있었습니다. 여행구성원간의 사전 여행계획 수립을 위해 숙소 가는법 같은 중요한 정보는 체크인 하루 전날에 알려주는게 아니라 빨리 제공해야합니다. 그리고 에어비앤비에 예약페이지에서 제공하는 숙소주소와 실 숙소의 주소가 다르다면 그 사실을 반드시 예약고객에게 알려줘야합니다. 호스트가 하루 전날 제공한 오는 방법에는 숙소의 주소가 나와있지 않기에 더욱 그렇습니다. 홍대역에서 도보로 숙소를 방문하지 않는 우리와 같은 예약고객도 있기 때문입니다. 우리는 에어비앤비에 등록된 숙소주소랑 실 숙소 주소가 다르다는걸 고지받지 못해서 영하 6도의 추운날에 짐 엄청 들고 숙소를 찾아 홍대를 돌아다녔습니다.',
#  '\n위치는 정말 좋았습니다. 다만 침구가 청결하지 못했습니다. 남자 머리카락들이 이불에 잔뜩있았습니다. 또 제가 먼지 알러지가 있는데 정말 힘들었습니다. 치약이 없어서 당황스러웠습니다. 집도 크고 위치도 좋았고 드라이기 2개, 호스트님과의 연락이 빠른점은 좋았습니다.',
#  '\n대응이 너무 늦었어요',
#  '\n다만 아쉬운점은 청소 상태가 아쉬운 부분입니다',
#  '\n전체적인 시설상태가 불량하고, 체크인시 청소가 되어있지 않고, 위생상태가 엉망입니다. 최악이었음 ㅜ.ㅜ',
#  '\n나는이 집의 청결 함에 실망했다. 나는 그것을 해결하기 위해 숙주와 함께 집을 가져왔다. 그러나 나는 결국 불행했다. 나는 Airbnb 집에 대한 나쁜 리뷰를 작성한 적이 없으며, 나는 매우 이해가 쉽다. 그러나이 리뷰는 매우 실망스럽고 화가 나있다. 호스트가 나와 함께 기꺼이 노력한다면 내 경험이 더 좋을 것이라고 생각합니다.',
#  '\n나쁘지 않았어요~ 1박 또는 2박만 이용할거라면 충분한 숙소입니다. 다만 아쉬웠던점은 의자 하나가 고장나 있었고, 세면대 물이 잘 내려가지 않았네요. 하지만 호스트님께서 빠르게 연락을 받아주셔서 괜찮았어요. 그동안 방문했던 다른 숙소들에 비해 비교적 별로였지만 기본적인 것들은 잘 갖춰진 숙소입니다. 좋은점은 언주역에서 6분거리라는점입니다.',
#  '\n에어비엔비의 시작이자 끝. 이제 그냥 호텔을 갈게요.',
#  '\n주차시설은 없다고 보시면 되세요..',
#  '\n해외에서 살고 있기 때문에 한국으로 2주간 휴가를 오는 동안 머물렀습니다. 처음에는 위치가 조금은 구석에 있어 앗? 하는 마음이 있었지만 주변에 조용하고 분위기 있는 맥주집과 편의점이 있어 그리 위험한 분위기는 아닙니다. 집도 깔끔하기는 하지만 에어컨이 조금은 덜 나오기는 합니다. 그 외에는 편하게 지낼 수 있는 조건이며 일단 강남역 등 주변을 한 정거장 거리로 걸어다닐 수 있다는 장점이 있습니다~ 잘 머물렀습니다^^ 강남역 근처 조용하고 가까운 곳 찾으시는 분들 추천드려요',
#  '\n정말오래된집이라 사진처럼 깨끗하고 깔끔한 분위기는 전혀아니에요, 조명도 어둡고 곳곳이 부식됐어요 늦은밤도착해 저렴한 가격에 잠만잔다면 모를까 추천하고 싶진않습니다',
#  '\n식기가 너무 더러워요~ 세제도 없어서 기다리기 귀찮아서 그냥 사다놨어요 ㅋㅋ 그거 외에는 사진이랑 똑같고 깨끗해용 들어가자마자 너무 따듯해서 좋아요!! 침구상태도 다 좋은데 부엌 식기 상태가 좀 ㅎㅎㅋㅋ 그거빼고는 다 완벽해요 ㅋㅋㅋ 그리고 폼클렌징이나 이런거는 다 따로챙겨가는게 좋을거같아요~~! ',
#  '\n전반적으로 깨끗한 편이었어요 사진과 달리 수건은 큰거 하나라 두명이서 쓰기 불편했어요 쓰기에 충분은 하지만... 길 찾기 쉽기는 하지만 건물과 건물 사이 틈이라 어두워서 여자끼리 다니긴 무서웠습니다',
#  '\n지하철 신논현역에서 가까우며 공항 버스 이용이 용이한 위치적인 장점, 친절한 호스트분의 안내가 만족스러웠습니다. 반면에 너무 낡은 숙소건물과 청소비용이 따로 청구됨에도 작은 카펫과 바닥에 많던 머리카락과 먼지, 냉장고 코드를 빼두어 냉장고를 열자마자 녹은 물이 흘러나온 점 등 사진에서와 같이 깔끔한 숙소는 아니니 청결도를 가장 우선으로 보시는 게스트분들께는 추천하지 않습니다.',
#  '\n화장실 청소상태나 침대커버에 붙어있는 머리카락들이며...청소비용지불을 해야하는게 맞나 하는 불쾌함이 남는 여행이었습니다',
#  '\n전반적으로 별로입니다. 늦은시간 급하게 저렴한 가격으로 머무실 분들에게 추천합니다. 1. 주차가 안됩니다. 일단 집앞 주차는 못하신다고 보시면 되고, 알려주신 근처 주차공간 역시 선착순일 뿐더러 멉니다. 따라서 이틀 이상 머무시는 경우 하루종일 주차해두기도 어렵습니다. 2. 청소가 불완전합니다. 저는 캐리어를 테이블 아랫쪽에 넣어줬는데, 쓰지 않는 와이파이 공유기 앞뒤양옆으로 먼지가 뭉쳐서 굴러다닙니다. 3. 불친절합니다. 제가 늦게 예약을 했다는 이유로(이것마저도 체크인 전) 8시 반에나
#  '\n전반적으로 깨끗한 편이었어요 사진과 달리 수건은 큰거 하나라 두명이서 쓰기 불편했어요 쓰기에 충분은 하지만... 길 찾기 쉽기는 하지만 건물과 건물 사이 틈이라 어두워서 여자끼리 다니긴 무서웠습니다',
#  '\n지하철 신논현역에서 가까우며 공항 버스 이용이 용이한 위치적인 장점, 친절한 호스트분의 안내가 만족스러웠습니다. \n 반면에 너무 낡은 숙소건물과 청소비용이 따로 청구됨에도 작은 카펫과 바닥에 많던 머리카락과 먼지, 냉장고 코드를 빼두어 냉장고를 열자마자 녹은 물이 흘러나온 점 등 사진에서와 같이 깔끔한 숙소는 아니니 청결도를 가장 우선으로 보시는 게스트분들께는 추천하지 않습니다.',
#  '\n네비따라 갔더니 집은 쉽게 찾을 수 있었어요.체크인 시간이 늦어진 점과 주차공간이 아쉬웠어요. 주차공간이 있다고 생각하고 갔는데, 혼잡한 서울의 교통 상황으로 차를 두고 다니는 동안 불안 불안..\n 친절하게 맞아주신 Mori mom님 감사해요. 깨끗하고 따뜻한 집에서 2박 잘 있다왔습니다.',
#  '\n전반적으로 별로입니다. 늦은시간 급하게 저렴한 가격으로 머무실 분들에게 추천합니다. 1. 주차가 안됩니다. 일단 집앞 주차는 못하신다고 보시면 되고, 알려주신 근처 주차공간 역시 선착순일 뿐더러 멉니다. 따라서 이틀 이상 머무시는 경우 하루종일 주차해두기도 어렵습니다. \n 2. 청소가 불완전합니다. 저는 캐리어를 테이블 아랫쪽에 넣어줬는데, 쓰지 않는 와이파이 공유기 앞뒤양옆으로 먼지가 뭉쳐서 굴러다닙니다. \n 3. 불친절합니다. 제가 늦게 예약을 했다는 이유로(이것마저도 체크인 전) 8시 반에나 체크인 할 수 있다고 하셨습니다. 물론 7시 반쯤 준비가 다 되었다고 오라고 하시긴 했는데, 날씨가 너무 추웠고 있을만한 공간이 없어서 이미 멀리 나온 상태였습니다. 의사 소통간 오해가 생겨도 굉장히 기분 나쁜투로 대답해주시고요.\n \n 이밖에도 화장실이 굉장히 춥다거나, 사진과 숙소 모습이 많이 다른것도 있습니다. 방 난방은 잘되고, 침대는 편안합니다.',
#  '\n']

# %%
# 후기 안좋은 숙소 빈도 계산
tf_vectorizer = CountVectorizer(min_df = 0.001, token_pattern=r'\w{2,}')

tf_corpus1 = tf_vectorizer.fit(message_of_guests)
tf_bow1 = tf_vectorizer.fit_transform(message_of_guests)
tf_bow1
# Out:
# <60x1527 sparse matrix of type '<class 'numpy.int64'>'
# 	with 2220 stored elements in Compressed Sparse Row format>

# %%
# 후기 안좋은 숙소 
print(len(tf_corpus1.vocabulary_))
print(len(tf_corpus1.get_feature_names()))
tf_vectorizer.get_feature_names()
# Out:
# 1527
# 1527
# ['1030',
#  '10분정도',
#  '11시',
#  '11시에는',
#  '12',
#  '12시',
#  '12시에',
#  '1박',
#  '1시간을',
#  '1층이긴',
#  '2개',
#  '2개있는',
#  '2명이서',
#  '2박',
#  '2박만',
#  '2주간',
#  '30',
#  '3분',
#  '3시간',
#  '3시이며',
#  '4시간',
#  '4층',
#  '5시간',
#  '5층같은',
#  '6도의',
#  '6분거리라는점입니다',
#  '7시',
#  '8명이',
#  '8시',
#  'airbnb',
#  'bad',
#  'good',
#  'mom님',
#  'mori',
#  'ㅋㅋ',
#  'ㅋㅋㅋ',
#  'ㅎㅎ',
#  'ㅎㅎㅋㅋ',
#  'ㅎㅎ너무',
#  'ㅠㅠ',
#  '가격값하는',
#  '가격대비',
#  '가격에',
#  '가격으로',
#  '가격은',
#  '가격이',
#  '가기엔',
#  '가까우며',
#  '가까운',
#  '가까운편이고',
#  '가까웠는데',
#  '가까웠습니다',
#  '가까이',
#  '가는',
#  '가는법',
#  '가도',
#  '가로등이',
#  '가야할듯',
#  '가요',
#  '가위',
#  '가장',
#  '가져',
#  '가져왔다',
#  '가지고',
#  '가질러갔어요',
#  '간다면',
#  '갈게요',
#  '갈아',
#  '감사합니다',
#  '감사해요',
#  '갔는데',
#  '갔더니',
#  '갔습니다',
#  '강남역',
#  '강남이랑',
#  '갖춰진',
#  '같네요',
#  '같습니다',
#  '같아요',
#  '같은',
#  '같이',
#  '개선되어야',
#  '개인의',
#  '거리',
#  '거리로',
#  '거리와',
#  '거부감이',
#  '거실',
#  '거의',
#  '거주자가',
#  '거주하고',
#  '건들거려서',
#  '건물',
#  '건물과',
#  '건물입구까지',
#  '걸려서',
#  '걸렸으므로',
#  '걸리고',
#  '걸린것',
#  '걸립니다',
#  '걸어다닐',
#  '걸으면',
#  '걸을때마다',
#  '검사',
#  '검사가',
#  '겁에',
#  '것들은',
#  '것을',
#  '것이',
#  '것이고',
#  '것이라고',
#  '것인지',
#  '게스트',
#  '게스트들에게',
#  '게스트분들께는',
#  '겨울이라',
#  '결국',
#  '결론',
#  '결정했습니다',
#  '경우',
#  '경우가',
#  '경험',
#  '경험이',
#  '경험인데',
#  '계단은',
#  '계신지',
#  '고려하신다',
#  '고려해야합니다',
#  '고시룸',
#  '고양이가',
#  '고장나',
#  '고장난',
#  '고정되어',
#  '고지받지',
#  '곳곳에',
#  '곳곳이',
#  '곳에',
#  '곳은',
#  '곳이었습니다',
#  '곳처럼',
#  '공간이',
#  '공백이생겨',
#  '공유기',
#  '공항',
#  '괜찮고',
#  '괜찮아요',
#  '괜찮았는데',
#  '괜찮았어요',
#  '괜찮은걸까',
#  '굉장히',
#  '교대역',
#  '교통',
#  '구분되어',
#  '구석등',
#  '구석에',
#  '굴러다닙니다',
#  '귀찮아서',
#  '그거',
#  '그거빼고는',
#  '그것',
#  '그것을',
#  '그것이',
#  '그게',
#  '그냥',
#  '그동안',
#  '그래도',
#  '그러나',
#  '그러나이',
#  '그런것들이',
#  '그런지',
#  '그럼에도',
#  '그렇습니다',
#  '그렇지',
#  '그로',
#  '그리',
#  '그리고',
#  '그에준비하셔서',
#  '그전엔',
#  '그제서야',
#  '극히',
#  '근데',
#  '근처',
#  '근처라',
#  '근처여서',
#  '급하게',
#  '기계',
#  '기계는',
#  '기꺼이',
#  '기능이',
#  '기다려야',
#  '기다려야합니다',
#  '기다리고',
#  '기다리기',
#  '기다릴',
#  '기다림',
#  '기본적인',
#  '기분',
#  '기타',
#  '기회가된다면',
#  '길을못찾아서',
#  '길치의',
#  '깔끔하고',
#  '깔끔하기는',
#  '깔끔한',
#  '깔끔했는데',
#  '깔끔했어요',
#  '깔려있어서',
#  '깔려있었어요',
#  '깨끗하고',
#  '깨끗하다고',
#  '깨끗한',
#  '깨끗한거였음',
#  '깨끗해용',
#  '끊겼지만요ㅠㅠ',
#  '끔찍하고',
#  '끔찍한',
#  '나갔다',
#  '나는',
#  '나는이',
#  '나쁘지',
#  '나쁜',
#  '나쁜투로',
#  '나오고',
#  '나오기는',
#  '나오기도',
#  '나온',
#  '나와',
#  '나와있지',
#  '나요',
#  '나있다',
#  '나중에',
#  '난방은',
#  '날씨가',
#  '날을',
#  '날이추워서',
#  '낡고',
#  '낡은',
#  '남는',
#  '남들이',
#  '남아있었고',
#  '남의',
#  '남자',
#  '났습니다',
#  '났었습니다',
#  '낭비했습니다',
#  '낮고',
#  '낮시간에는',
#  '내려가지',
#  '내려서',
#  '내로',
#  '내리지',
#  '냄새가',
#  '냄새는',
#  '냉동실',
#  '냉장고',
#  '냉장고가',
#  '냉장고를',
#  '냉장고에는',
#  '너무',
#  '너무가깝고',
#  '너무좋고',
#  '넉넉하게',
#  '넉넉히',
#  '넓어서',
#  '넓은',
#  '넣어도',
#  '넣어줬는데',
#  '네비따라',
#  '년경에',
#  '노력한다면',
#  '노트북을',
#  '노후된',
#  '녹은',
#  '놀다가',
#  '놀라고',
#  '놀랐어요',
#  '놀러가기',
#  '높고',
#  '놓겠다고',
#  '놓고',
#  '놔두고',
#  '놔둔건지',
#  '누가',
#  '누구나',
#  '누르는',
#  '느껴지진',
#  '느낌을',
#  '느낌임',
#  '늦게',
#  '늦고',
#  '늦어지니',
#  '늦어진',
#  '늦었어요',
#  '늦은밤도착해',
#  '늦은시간',
#  '다니긴',
#  '다니는',
#  '다르다는걸',
#  '다르다면',
#  '다른',
#  '다른것도',
#  '다른곳은',
#  '다름',
#  '다만',
#  '다소',
#  '다시',
#  '다시는',
#  '다음',
#  '다음날',
#  '다음에',
#  '단무지도',
#  '단점이',
#  '달라서',
#  '달리',
#  '당시',
#  '당일',
#  '당황스러웠습니다',
#  '대답하는',
#  '대답해주시고요',
#  '대응이',
#  '대체적으로',
#  '대한',
#  '대해',
#  '대해서',
#  '더러운',
#  '더러움',
#  '더러워서',
#  '더러워요',
#  '더러워져요',
#  '더럽고',
#  '더욱',
#  '덕분에',
#  '덜덜',
#  '데오데란트',
#  '데우고나니',
#  '데워서',
#  '도구가',
#  '도보로',
#  '도심이라',
#  '도착시간을',
#  '도착한',
#  '도착했음에도',
#  '돌아가서',
#  '돌아감',
#  '돌아다녔습니다',
#  '동동거리지않아도되고',
#  '동안',
#  '되게',
#  '되겠네요',
#  '되고',
#  '되세요',
#  '되어',
#  '되어서',
#  '되어있어서',
#  '되어있지',
#  '되었다고',
#  '되었습니다',
#  '되있어서',
#  '되지',
#  '됩니다',
#  '두고',
#  '두명이서',
#  '두번',
#  '두분이랑',
#  '뒤에',
#  '드는데',
#  '드라이기',
#  '들고',
#  '들려서',
#  '들르시는',
#  '들리지',
#  '들림',
#  '들어',
#  '들어가기',
#  '들어가는데',
#  '들어가보니',
#  '들어가자마자',
#  '들어갈',
#  '들어갔음',
#  '들어오는',
#  '들어오면',
#  '들어옴',
#  '들었어요',
#  '들었음',
#  '들지',
#  '듭니다',
#  '등도',
#  '등등',
#  '등록된',
#  '따듯한',
#  '따듯해서',
#  '따뜻하고',
#  '따뜻하더라구요',
#  '따뜻한',
#  '따뜻함',
#  '따뜻해지는데',
#  '따라서',
#  '따로',
#  '따로챙겨가는게',
#  '딸려',
#  '때문에',
#  '때문입니다',
#  '떠난',
#  '떠났다',
#  '떼탔거나',
#  '또는',
#  '또한',
#  '똑같고',
#  '똑같아서',
#  '뜯어져있고',
#  '로션',
#  '리뷰는',
#  '리뷰들을',
#  '리뷰를',
#  '마땅히',
#  '마실',
#  '마음에',
#  '마음이',
#  '막히거나',
#  '만든다',
#  '만족스러웠습니다',
#  '만한',
#  '많던',
#  '많아서',
#  '많았구요',
#  '많았음',
#  '많으신분들은',
#  '많이',
#  '말고는',
#  '말도록',
#  '말하며',
#  '맞나',
#  '맞는',
#  '맞아주신',
#  '매우',
#  '매트리스가',
#  '맥주집과',
#  '머리카락과',
#  '머리카락도',
#  '머리카락들이',
#  '머리카락들이며',
#  '머무르기에',
#  '머무시는',
#  '머무실',
#  '머물렀습니다',
#  '먹기엔',
#  '먹었을뿐',
#  '먹으려했는지',
#  '먹을곳도',
#  '먼지',
#  '먼지가',
#  '멀리',
#  '멀지않은',
#  '멉니다',
#  '메시지를',
#  '면도기',
#  '모기',
#  '모던하고',
#  '모두',
#  '모두가',
#  '모든',
#  '모르겠다',
#  '모르겠지만',
#  '모르는',
#  '모르지만',
#  '모를',
#  '모를까',
#  '모습',
#  '모습이',
#  '목소리가',
#  '목욕',
#  '목적으로',
#  '몹시',
#  '못써서',
#  '못하겠네요',
#  '못하신다고',
#  '못해서',
#  '못했는데',
#  '못했다',
#  '못했습니다',
#  '무릅쓰고',
#  '무리같네요ㅎㅎ',
#  '무서움을',
#  '무서웠습니다',
#  '무서웠어요',
#  '무슨',
#  '무엇보다',
#  '무작정',
#  '묵고',
#  '묵기',
#  '묵기에는',
#  '묵을',
#  '문앞에',
#  '문에서인사해줘서',
#  '문을',
#  '문제가',
#  '문제를',
#  '문제없이',
#  '물건을',
#  '물도',
#  '물론',
#  '물에',
#  '물을',
#  '물이',
#  '물품들이',
#  '뭉쳐서',
#  '미리',
#  '밑에',
#  '밑의',
#  '바깥소음은',
#  '바꾸고',
#  '바닥',
#  '바닥과',
#  '바닥에',
#  '바닥이',
#  '바디',
#  '바라는건',
#  '바랍니다',
#  '바로',
#  '바로바로',
#  '밖에',
#  '밖에서',
#  '밖에서도',
#  '밖이랑',
#  '반드시',
#  '반면에',
#  '반에나',
#  '반지하라',
#  '반지하였습니다',
#  '반쯤',
#  '받아주셔서',
#  '받았는데',
#  '받았다',
#  '받지',
#  '발견',
#  '발이',
#  '밟으면',
#  '밤까지',
#  '밤마다',
#  '밤에',
#  '밥먹을',
#  '방데우고',
#  '방데워지는데',
#  '방도',
#  '방들보다',
#  '방문하지',
#  '방문했던',
#  '방법만',
#  '방법에는',
#  '방법은',
#  '방법을',
#  '방에',
#  '방에도',
#  '방은',
#  '방을',
#  '방음은',
#  '방음이',
#  '방이',
#  '방이었습니다',
#  '방인데',
#  '방청소함',
#  '방크기도',
#  '버스',
#  '버스정류장과',
#  '번호로',
#  '벗겨지거나',
#  '벽지도',
#  '벽지에',
#  '변경하십시오',
#  '변경한다고',
#  '변명과',
#  '별로',
#  '별로였고',
#  '별로였습니다',
#  '별로였지만',
#  '별로입니다',
#  '보고',
#  '보내준',
#  '보며',
#  '보면',
#  '보시는',
#  '보시면',
#  '보여서',
#  '보이네요ㅠㅠ',
#  '보일러',
#  '보일러도',
#  '보일러로',
#  '보일러를',
#  '보일러키니까',
#  '보지',
#  '본인이',
#  '볼때마다',
#  '부분은',
#  '부분인거',
#  '부분입니다',
#  '부식됐어요',
#  '부엌',
#  '부엌은',
#  '부족하고',
#  '부족하실',
#  '부족함',
#  '분들',
#  '분들에게',
#  '분에',
#  '분위기',
#  '분위기는',
#  '분이',
#  '분한테는',
#  '불구하고',
#  '불량하고',
#  '불만족스러운',
#  '불안',
#  '불안정해서',
#  '불안합니다',
#  '불안했고요',
#  '불안했던것',
#  '불완전합니다',
#  '불친절합니다',
#  '불쾌할',
#  '불쾌함이',
#  '불편없어요',
#  '불편한점은',
#  '불편했구요',
#  '불편했습니다',
#  '불편했어요',
#  '불폈했어요',
#  '불평하는',
#  '불행했다',
#  '붙어있는',
#  '붙어있어',
#  '비가',
#  '비교적',
#  '비꼼으로',
#  '비밀',
#  '비밀번호',
#  '비밀번호가',
#  '비위가',
#  '비지',
#  '비품이없어서',
#  '비해',
#  '비해서',
#  '빔프로젝트있어서',
#  '빠르게',
#  '빠르구요',
#  '빠른점은',
#  '빠지기가',
#  '빠지는데',
#  '빨리',
#  '빵빵해서',
#  '빼두어',
#  '뿐더러',
#  '사다놨어요',
#  '사람',
#  '사람들이',
#  '사실상',
#  '사실을',
#  '사용에',
#  '사용은',
#  '사용하기',
#  '사용하려고했지만',
#  '사용하여',
#  '사용했던',
#  '사이',
#  '사이트를',
#  '사이트에',
#  '사전',
#  '사전에',
#  '사진과',
#  '사진보다',
#  '사진보다는',
#  '사진빨이에요',
#  '사진에서와',
#  '사진으로',
#  '사진이',
#  '사진이랑',
#  '사진처럼',
#  '살고',
#  '살짝',
#  '샀다',
#  '상기시켜줍니다',
#  '상당히',
#  '상쾌하지',
#  '상태가',
#  '상태도',
#  '상태로',
#  '상태를',
#  '상태였고',
#  '상태였습니다',
#  '상황으로',
#  '생각되네요',
#  '생각보다',
#  '생각하고',
#  '생각합니다',
#  '생각했습니다',
#  '생겨도',
#  '생활에는',
#  '생활용품이',
#  '샤워',
#  '샤워는',
#  '샤워를',
#  '샤워를하기',
#  '샤워하기',
#  '샤워할때',
#  '샴푸',
#  '샴푸를',
#  '샴푸린스바디클렌징폼',
#  '서서',
#  '서울의',
#  '서초쪽',
#  '선착순일',
#  '세면대',
#  '세면대에',
#  '세입자가',
#  '세입자를주지',
#  '세제도',
#  '세탁기는',
#  '세탁기를',
#  '세탁하고',
#  '셀프로',
#  '셌음',
#  '셔츠를',
#  '셔파에',
#  '소개에',
#  '소리도',
#  '소리에',
#  '소유자가',
#  '소유자는',
#  '소유자에게',
#  '소음은',
#  '소통간',
#  '소통도',
#  '소통은',
#  '손님',
#  '솔직히',
#  '쇼파도',
#  '수건',
#  '수건도',
#  '수건은',
#  '수건이',
#  '수도',
#  '수도공사로',
#  '수립을',
#  '수압도',
#  '수준을',
#  '수집하는건지',
#  '수화물을',
#  '숙박예정인',
#  '숙박하기엔',
#  '숙소',
#  '숙소건물과',
#  '숙소는',
#  '숙소들에',
#  '숙소라고',
#  '숙소로',
#  '숙소를',
#  '숙소에',
#  '숙소였어요',
#  '숙소위치가',
#  '숙소의',
#  '숙소입니다',
#  '숙소주소는',
#  '숙소주소랑',
#  '숙소주소로',
#  '숙소주소와',
#  '숙주와',
#  '쉬고',
#  '쉽게',
#  '쉽기는',
#  '쉽다',
#  '슈퍼랑',
#  '스스로',
#  '슬리퍼가',
#  '시간보다',
#  '시간으로부터',
#  '시간은',
#  '시간을',
#  '시간이',
#  '시경에',
#  '시설',
#  '시설상태가',
#  '시설은',
#  '시작이자',
#  '시체가',
#  '식기',
#  '식기가',
#  '신경써주셨으면',
#  '신경이',
#  '신논현역',
#  '신논현역에서',
#  '신중해질꺼같네요',
#  '실망스럽고',
#  '실망했다',
#  '실제로',
#  '심지어',
#  '싱글이라서',
#  '싶게',
#  '싶어요',
#  '싶지',
#  '싶진않습니다',
#  '써야하는게',
#  '써져',
#  '썼습니다',
#  '쓰고',
#  '쓰기',
#  '쓰기에',
#  '쓰라고',
#  '쓰레기통도',
#  '쓰실수',
#  '쓰심',
#  '쓰였습니다',
#  '쓰지',
#  '쓸모가',
#  '씻기',
#  '아니니',
#  '아니라',
#  '아니지만',
#  '아닙니다',
#  '아랫쪽에',
#  '아무',
#  '아쉬운',
#  '아쉬운건',
#  '아쉬운점은',
#  '아쉬움이',
#  '아쉬웠던',
#  '아쉬웠던점은',
#  '아쉬웠어요',
#  '아쉽습니다',
#  '아주',
#  '악취가',
#  '안나와서',
#  '안내가',
#  '안내도',
#  '안내려가서',
#  '안내를',
#  '안돼서',
#  '안되고',
#  '안되는듯',
#  '안된것이고',
#  '안될뻔한것도',
#  '안됩니다',
#  '안들려서',
#  '안락한',
#  '안보였습니다',
#  '안의',
#  '안했지만',
#  '앉아',
#  '앉아먹기엔',
#  '않고',
#  '않기에',
#  '않는',
#  '않더라고요',
#  '않습니다',
#  '않아',
#  '않아서',
#  '않아요',
#  '않았네요',
#  '않았습니다',
#  '않았어요',
#  '않았으며',
#  '않았음',
#  '않았지만',
#  '않으면',
#  '않으시겠습니까',
#  '않은',
#  '않을',
#  '않음',
#  '알러지가',
#  '알려달라',
#  '알려드렸고',
#  '알려주는',
#  '알려주는게',
#  '알려주신',
#  '알려줘야합니다',
#  '알리는',
#  '알리십시오',
#  '암호를',
#  '앞뒤양옆으로',
#  '약간',
#  '약간의',
#  '양호한',
#  '어느',
#  '어두워서',
#  '어둡고',
#  '어디인지',
#  '어려우며',
#  '어렵습니다',
#  '언제',
#  '언주역에서',
#  '엄청',
#  '없고',
#  '없는',
#  '없는게',
#  '없다',
#  '없다고',
#  '없어서',
#  '없었구요',
#  '없었다',
#  '없었던',
#  '없었습니다',
#  '없었으며',
#  '없으니',
#  '없으며',
#  '없으면',
#  '없음',
#  '없이',
#  '엉뚱한',
#  '엉망입니다',
#  '에그',
#  '에어비앤비',
#  '에어비앤비에',
#  '에어비앤비에서',
#  '에어비엔비의',
#  '에어앤비의',
#  '에어컨이',
#  '엘레베이터가',
#  '여기로',
#  '여자끼리',
#  '여행',
#  '여행계획',
#  '여행구성원간의',
#  '여행을',
#  '여행이',
#  '여행이었습니다',
#  '역시',
#  '역에서',
#  '역이랑',
#  '연락',
#  '연락도',
#  '연락을',
#  '연락이',
#  '연락하면',
#  '연락하였으나',
#  '열릴수',
#  '열어놓으셔서',
#  '열자마자',
#  '영하',
#  '옆의',
#  '옆집에서',
#  '예쁘고',
#  '예약고객도',
#  '예약고객에게',
#  '예약시',
#  '예약을',
#  '예약페이지에서',
#  '예약한',
#  '예약했지만',
#  '예정된',
#  '오기를',
#  '오는',
#  '오라고',
#  '오래되었다는',
#  '오래되었습니다',
#  '오랜',
#  '오전',
#  '오지',
#  '오피스텔이었구요',
#  '오해가',
#  '오후',
#  '온돌로',
#  '온수',
#  '온수가',
#  '온수공급이',
#  '온수작동이',
#  '온수잘나오고',
#  '올라오지않을까',
#  '옷을',
#  '와서',
#  '와야',
#  '와이파이',
#  '와이파이가',
#  '와주셔서',
#  '완벽해요',
#  '완전히',
#  '왔습니다',
#  '왔어',
#  '외국인들이',
#  '외에',
#  '외에는',
#  '외출로',
#  '요청해야한다고',
#  '요청했었는데',
#  '욕실',
#  '욕실과',
#  '욕실에서',
#  '욕실은',
#  '욕실의',
#  '욕실이',
#  '욕조가',
#  '용도면에서는',
#  '용이한',
#  '우리',
#  '우리가',
#  '우리는',
#  '우리에게는',
#  '우리와',
#  '우리일행은',
#  '우선',
#  '우선으로',
#  '우유',
#  '울렸습니다',
#  ...]

# %%
# 후기 안좋은 숙소
# frequency count
tf_word_sum1 = tf_bow1.toarray().sum(axis=0)
tf_word_name1 = tf_corpus1.get_feature_names()
tf_word_dict1 = {}

for i in range(len(tf_word_sum1)):
    tf_word_dict1[tf_word_name1[i]] = tf_word_sum1[i]
    
print(tf_corpus1.get_feature_names())
tf_word_sum1
# Out:
누르는', '느껴지진', '느낌을', '느낌임', '늦게', '늦고', '늦어지니', '늦어진', '늦었어요', '늦은밤도착해', '늦은시간', '다니긴', '다니는', '다르다는걸', '다르다면', '다른', '다른것도', '다른곳은', '다름', '다만', '다소', '다시', '다시는', '다음', '다음날', '다음에', '단무지도', '단점이', '달라서', '달리', '당시', '당일', '당황스러웠습니다', '대답하는', '대답해주시고요', '대응이', '대체적으로', '대한', '대해', '대해서', '더러운', '더러움', '더러워서', '더러워요', '더러워져요', '더럽고', '더욱', '덕분에', '덜덜', '데오데란트', '데우고나니', '데워서', '도구가', '도보로', '도심이라', '도착시간을', '도착한', '도착했음에도', '돌아가서', '돌아감', '돌아다녔습니다', '동동거리지않아도되고', '동안', '되게', '되겠네요', '되고', '되세요', '되어', '되어서', '되어있어서', '되어있지', '되었다고', '되었습니다', '되있어서', '되지', '됩니다', '두고', '두명이서', '두번', '두분이랑', '뒤에', '드는데', '드라이기', '들고', '들려서', '들르시는', '들리지', '들림', '들어', '들어가기', '들어가는데', '들어가보니', '들어가자마자', '들어갈', '들어갔음', '들어오는', '들어오면', '들어옴', '들었어요', '들었음', '들지', '듭니다', '등도', '등등', '등록된', '따듯한', '따듯해서', '따뜻하고', '따뜻하더라구요', '따뜻한', '따뜻함', '따뜻해지는데', '따라서', '따로', '따로챙겨가는게', '딸려', '때문에', '때문입니다', '떠난', '떠났다', '떼탔거나', '또는', '또한', '똑같고', '똑같아서', '뜯어져있고', '로션', '리뷰는', '리뷰들을', '리뷰를', '마땅히', '마실', '마음에', '마음이', '막히거나', '만든다', '만족스러웠습니다', '만한', '많던', '많아서', '많았구요', '많았음', '많으신분들은', '많이', '말고는', '말도록', '말하며', '맞나', '맞는', '맞아주신', '매우', '매트리스가', '맥주집과', '머리카락과', '머리카락도', '머리카락들이', '머리카락들이며', '머무르기에', '머무시는', '머무실', '머물렀습니다', '먹기엔', '먹었을뿐', '먹으려했는지', '먹을곳도', '먼지', '먼지가', '멀리', '멀지않은', '멉니다', '메시지를', '면도기', '모기', '모던하고', '모두', '모두가', '모든', '모르겠다', '모르겠지만', '모르는', '모르지만', '모를', '모를까', '모습', '모습이', '목소리가', '목욕', '목적으로', '몹시', '못써서', '못하겠네요', '못하신다고', '못해서', '못했는데', '못했다', '못했습니다', '무릅쓰고', '무리같네요ㅎㅎ', '무서움을', '무서웠습니다', '무서웠어요', '무슨', '무엇보다', '무작정', '묵고', '묵기', '묵기에는', '묵을', '문앞에', '문에서인사해줘서', '문을', '문제가', '문제를', '문제없이', '물건을', '물도', '물론', '물에', '물을', '물이', '물품들이', '뭉쳐서', '미리', '밑에', '밑의', '바깥소음은', '바꾸고', '바닥', '바닥과', '바닥에', '바닥이', '바디', '바라는건', '바랍니다', '바로', '바로바로', '밖에', '밖에서', '밖에서도', '밖이랑', '반드시', '반면에', '반에나', '반지하라', '반지하였습니다', '반쯤', '받아주셔서', '받았는데', '받았다', '받지', '발견', '발이', '밟으면', '밤까지' ...
# array([1, 1, 2, ..., 3, 1, 2], dtype=int64)

# %%
# 후기 안좋은 숙소
# 단어별 글자수 확인
tf_word_dict1
# Out:
# {'1030': 1,
#  '10분정도': 1,
#  '11시': 2,
#  '11시에는': 1,
#  '12': 1,
#  '12시': 1,
#  '12시에': 1,
#  '1박': 1,
#  '1시간을': 1,
#  '1층이긴': 1,
#  '2개': 2,
#  '2개있는': 2,
#  '2명이서': 1,
#  '2박': 1,
#  '2박만': 1,
#  '2주간': 1,
#  '30': 2,
#  '3분': 1,
#  '3시간': 1,
#  '3시이며': 1,
#  '4시간': 2,
#  '4층': 1,
#  '5시간': 1,
#  '5층같은': 1,
#  '6도의': 1,
#  '6분거리라는점입니다': 1,
#  '7시': 2,
#  '8명이': 1,
#  '8시': 2,
#  'airbnb': 1,
#  'bad': 1,
#  'good': 1,
#  'mom님': 1,
#  'mori': 1,
#  'ㅋㅋ': 2,
#  'ㅋㅋㅋ': 2,
#  'ㅎㅎ': 1,
#  'ㅎㅎㅋㅋ': 2,
#  'ㅎㅎ너무': 1,
#  'ㅠㅠ': 2,
#  '가격값하는': 1,
#  '가격대비': 2,
#  '가격에': 3,
#  '가격으로': 3,
#  '가격은': 1,
#  '가격이': 2,
#  '가기엔': 2,
#  '가까우며': 2,
#  '가까운': 2,
#  '가까운편이고': 1,
#  '가까웠는데': 1,
#  '가까웠습니다': 2,
#  '가까이': 2,
#  '가는': 2,
#  '가는법': 1,
#  '가도': 1,
#  '가로등이': 2,
#  '가야할듯': 2,
#  '가요': 1,
#  '가위': 1,
#  '가장': 3,
#  '가져': 1,
#  '가져왔다': 1,
#  '가지고': 1,
#  '가질러갔어요': 1,
#  '간다면': 1,
#  '갈게요': 1,
#  '갈아': 1,
#  '감사합니다': 1,
#  '감사해요': 1,
#  '갔는데': 3,
#  '갔더니': 1,
#  '갔습니다': 1,
#  '강남역': 3,
#  '강남이랑': 1,
#  '갖춰진': 1,
#  '같네요': 2,
#  '같습니다': 2,
#  '같아요': 2,
#  '같은': 5,
#  '같이': 2,
#  '개선되어야': 2,
#  '개인의': 2,
#  '거리': 1,
#  '거리로': 1,
#  '거리와': 1,
#  '거부감이': 1,
#  '거실': 1,
#  '거의': 1,
#  '거주자가': 1,
#  '거주하고': 1,
#  '건들거려서': 1,
#  '건물': 2,
#  '건물과': 2,
#  '건물입구까지': 2,
#  '걸려서': 1,
#  '걸렸으므로': 1,
#  '걸리고': 1,
#  '걸린것': 1,
#  '걸립니다': 1,
#  '걸어다닐': 1,
#  '걸으면': 1,
#  '걸을때마다': 1,
#  '검사': 1,
#  '검사가': 1,
#  '겁에': 1,
#  '것들은': 1,
#  '것을': 2,
#  '것이': 1,
#  '것이고': 1,
#  '것이라고': 2,
#  '것인지': 2,
#  '게스트': 2,
#  '게스트들에게': 2,
#  '게스트분들께는': 2,
#  '겨울이라': 1,
#  '결국': 3,
#  '결론': 2,
#  '결정했습니다': 1,
#  '경우': 3,
#  '경우가': 1,
#  '경험': 1,
#  '경험이': 2,
#  '경험인데': 1,
#  '계단은': 1,
#  '계신지': 1,
#  '고려하신다': 1,
#  '고려해야합니다': 1,
#  '고시룸': 1,
#  '고양이가': 1,
#  '고장나': 1,
#  '고장난': 1,
#  '고정되어': 1,
#  '고지받지': 1,
#  '곳곳에': 2,
#  '곳곳이': 2,
#  '곳에': 1,
#  '곳은': 1,
#  '곳이었습니다': 1,
#  '곳처럼': 1,
#  '공간이': 2,
#  '공백이생겨': 1,
#  '공유기': 2,
#  '공항': 2,
#  '괜찮고': 1,
#  '괜찮아요': 1,
#  '괜찮았는데': 1,
#  '괜찮았어요': 1,
#  '괜찮은걸까': 1,
#  '굉장히': 9,
#  '교대역': 1,
#  '교통': 1,
#  '구분되어': 1,
#  '구석등': 2,
#  '구석에': 1,
#  '굴러다닙니다': 2,
#  '귀찮아서': 2,
#  '그거': 2,
#  '그거빼고는': 2,
#  '그것': 1,
#  '그것을': 2,
#  '그것이': 1,
#  '그게': 2,
#  '그냥': 3,
#  '그동안': 2,
#  '그래도': 4,
#  '그러나': 6,
#  '그러나이': 1,
#  '그런것들이': 2,
#  '그런지': 1,
#  '그럼에도': 1,
#  '그렇습니다': 1,
#  '그렇지': 1,
#  '그로': 1,
#  '그리': 1,
#  '그리고': 12,
#  '그에준비하셔서': 1,
#  '그전엔': 1,
#  '그제서야': 1,
#  '극히': 1,
#  '근데': 2,
#  '근처': 3,
#  '근처라': 1,
#  '근처여서': 1,
#  '급하게': 2,
#  '기계': 1,
#  '기계는': 1,
#  '기꺼이': 1,
#  '기능이': 1,
#  '기다려야': 1,
#  '기다려야합니다': 1,
#  '기다리고': 1,
#  '기다리기': 2,
#  '기다릴': 1,
#  '기다림': 1,
#  '기본적인': 2,
#  '기분': 2,
#  '기타': 1,
#  '기회가된다면': 1,
#  '길을못찾아서': 1,
#  '길치의': 1,
#  '깔끔하고': 1,
#  '깔끔하기는': 1,
#  '깔끔한': 4,
#  '깔끔했는데': 1,
#  '깔끔했어요': 1,
#  '깔려있어서': 1,
#  '깔려있었어요': 1,
#  '깨끗하고': 3,
#  '깨끗하다고': 1,
#  '깨끗한': 2,
#  '깨끗한거였음': 1,
#  '깨끗해용': 2,
#  '끊겼지만요ㅠㅠ': 1,
#  '끔찍하고': 1,
#  '끔찍한': 1,
#  '나갔다': 2,
#  '나는': 7,
#  '나는이': 1,
#  '나쁘지': 2,
#  '나쁜': 2,
#  '나쁜투로': 2,
#  '나오고': 2,
#  '나오기는': 1,
#  '나오기도': 1,
#  '나온': 2,
#  '나와': 1,
#  '나와있지': 2,
#  '나요': 1,
#  '나있다': 1,
#  '나중에': 1,
#  '난방은': 2,
#  '날씨가': 2,
#  '날을': 1,
#  '날이추워서': 1,
#  '낡고': 1,
#  '낡은': 2,
#  '남는': 2,
#  '남들이': 2,
#  '남아있었고': 1,
#  '남의': 2,
#  '남자': 1,
#  '났습니다': 1,
#  '났었습니다': 1,
#  '낭비했습니다': 1,
#  '낮고': 1,
#  '낮시간에는': 1,
#  '내려가지': 1,
#  '내려서': 1,
#  '내로': 1,
#  '내리지': 1,
#  '냄새가': 3,
#  '냄새는': 1,
#  '냉동실': 1,
#  '냉장고': 3,
#  '냉장고가': 1,
#  '냉장고를': 2,
#  '냉장고에는': 2,
#  '너무': 17,
#  '너무가깝고': 1,
#  '너무좋고': 1,
#  '넉넉하게': 1,
#  '넉넉히': 1,
#  '넓어서': 2,
#  '넓은': 1,
#  '넣어도': 1,
#  '넣어줬는데': 2,
#  '네비따라': 1,
#  '년경에': 1,
#  '노력한다면': 1,
#  '노트북을': 1,
#  '노후된': 1,
#  '녹은': 2,
#  '놀다가': 1,
#  '놀라고': 1,
#  '놀랐어요': 1,
#  '놀러가기': 1,
#  '높고': 1,
#  '놓겠다고': 1,
#  '놓고': 1,
#  '놔두고': 2,
#  '놔둔건지': 2,
#  '누가': 1,
#  '누구나': 1,
#  '누르는': 2,
#  '느껴지진': 1,
#  '느낌을': 1,
#  '느낌임': 2,
#  '늦게': 2,
#  '늦고': 1,
#  '늦어지니': 1,
#  '늦어진': 1,
#  '늦었어요': 1,
#  '늦은밤도착해': 2,
#  '늦은시간': 2,
#  '다니긴': 2,
#  '다니는': 1,
#  '다르다는걸': 1,
#  '다르다면': 1,
#  '다른': 6,
#  '다른것도': 2,
#  '다른곳은': 1,
#  '다름': 2,
#  '다만': 10,
#  '다소': 1,
#  '다시': 1,
#  '다시는': 2,
#  '다음': 5,
#  '다음날': 1,
#  '다음에': 1,
#  '단무지도': 1,
#  '단점이': 1,
#  '달라서': 1,
#  '달리': 2,
#  '당시': 1,
#  '당일': 2,
#  '당황스러웠습니다': 1,
#  '대답하는': 2,
#  '대답해주시고요': 2,
#  '대응이': 1,
#  '대체적으로': 1,
#  '대한': 2,
#  '대해': 1,
#  '대해서': 2,
#  '더러운': 1,
#  '더러움': 2,
#  '더러워서': 1,
#  '더러워요': 2,
#  '더러워져요': 1,
#  '더럽고': 3,
#  '더욱': 1,
#  '덕분에': 1,
#  '덜덜': 1,
#  '데오데란트': 2,
#  '데우고나니': 1,
#  '데워서': 2,
#  '도구가': 1,
#  '도보로': 3,
#  '도심이라': 1,
#  '도착시간을': 1,
#  '도착한': 2,
#  '도착했음에도': 1,
#  '돌아가서': 1,
#  '돌아감': 1,
#  '돌아다녔습니다': 1,
#  '동동거리지않아도되고': 1,
#  '동안': 2,
#  '되게': 3,
#  '되겠네요': 1,
#  '되고': 2,
#  '되세요': 2,
#  '되어': 2,
#  '되어서': 2,
#  '되어있어서': 1,
#  '되어있지': 1,
#  '되었다고': 2,
#  '되었습니다': 1,
#  '되있어서': 1,
#  '되지': 2,
#  '됩니다': 1,
#  '두고': 1,
#  '두명이서': 2,
#  '두번': 2,
#  '두분이랑': 1,
#  '뒤에': 1,
#  '드는데': 1,
#  '드라이기': 1,
#  '들고': 1,
#  '들려서': 1,
#  '들르시는': 1,
#  '들리지': 1,
#  '들림': 2,
#  '들어': 1,
#  '들어가기': 1,
#  '들어가는데': 2,
#  '들어가보니': 1,
#  '들어가자마자': 2,
#  '들어갈': 2,
#  '들어갔음': 2,
#  '들어오는': 1,
#  '들어오면': 1,
#  '들어옴': 2,
#  '들었어요': 1,
#  '들었음': 1,
#  '들지': 1,
#  '듭니다': 1,
#  '등도': 1,
#  '등등': 2,
#  '등록된': 1,
#  '따듯한': 1,
#  '따듯해서': 2,
#  '따뜻하고': 1,
#  '따뜻하더라구요': 1,
#  '따뜻한': 3,
#  '따뜻함': 2,
#  '따뜻해지는데': 1,
#  '따라서': 2,
#  '따로': 3,
#  '따로챙겨가는게': 2,
#  '딸려': 1,
#  '때문에': 3,
#  '때문입니다': 1,
#  '떠난': 1,
#  '떠났다': 1,
#  '떼탔거나': 1,
#  '또는': 1,
#  '또한': 1,
#  '똑같고': 2,
#  '똑같아서': 1,
#  '뜯어져있고': 2,
#  '로션': 2,
#  '리뷰는': 1,
#  '리뷰들을': 2,
#  '리뷰를': 2,
#  '마땅히': 1,
#  '마실': 1,
#  '마음에': 1,
#  '마음이': 1,
#  '막히거나': 1,
#  '만든다': 1,
#  '만족스러웠습니다': 4,
#  '만한': 1,
#  '많던': 2,
#  '많아서': 4,
#  '많았구요': 1,
#  '많았음': 1,
#  '많으신분들은': 1,
#  '많이': 9,
#  '말고는': 1,
#  '말도록': 1,
#  '말하며': 1,
#  '맞나': 1,
#  '맞는': 1,
#  '맞아주신': 1,
#  '매우': 3,
#  '매트리스가': 1,
#  '맥주집과': 1,
#  '머리카락과': 2,
#  '머리카락도': 1,
#  '머리카락들이': 3,
#  '머리카락들이며': 1,
#  '머무르기에': 1,
#  '머무시는': 2,
#  '머무실': 2,
#  '머물렀습니다': 2,
#  '먹기엔': 1,
#  '먹었을뿐': 1,
#  '먹으려했는지': 1,
#  '먹을곳도': 1,
#  '먼지': 4,
#  '먼지가': 3,
#  '멀리': 2,
#  '멀지않은': 1,
#  '멉니다': 2,
#  '메시지를': 1,
#  '면도기': 2,
#  '모기': 1,
#  '모던하고': 1,
#  '모두': 1,
#  '모두가': 1,
#  '모든': 1,
#  '모르겠다': 1,
#  '모르겠지만': 2,
#  '모르는': 1,
#  '모르지만': 1,
#  '모를': 1,
#  '모를까': 2,
#  '모습': 2,
#  '모습이': 2,
#  '목소리가': 1,
#  '목욕': 1,
#  '목적으로': 1,
#  '몹시': 1,
#  '못써서': 1,
#  '못하겠네요': 1,
#  '못하신다고': 2,
#  '못해서': 1,
#  '못했는데': 1,
#  '못했다': 1,
#  '못했습니다': 2,
#  '무릅쓰고': 2,
#  '무리같네요ㅎㅎ': 1,
#  '무서움을': 2,
#  '무서웠습니다': 2,
#  '무서웠어요': 2,
#  '무슨': 1,
#  '무엇보다': 1,
#  '무작정': 1,
#  '묵고': 1,
#  '묵기': 1,
#  '묵기에는': 1,
#  '묵을': 1,
#  '문앞에': 1,
#  '문에서인사해줘서': 1,
#  '문을': 1,
#  '문제가': 1,
#  '문제를': 1,
#  '문제없이': 1,
#  '물건을': 2,
#  '물도': 2,
#  '물론': 2,
#  '물에': 1,
#  '물을': 2,
#  '물이': 6,
#  '물품들이': 1,
#  '뭉쳐서': 2,
#  '미리': 1,
#  '밑에': 2,
#  '밑의': 1,
#  '바깥소음은': 1,
#  '바꾸고': 1,
#  '바닥': 1,
#  '바닥과': 1,
#  '바닥에': 5,
#  '바닥이': 1,
#  '바디': 1,
#  '바라는건': 1,
#  '바랍니다': 1,
#  '바로': 1,
#  '바로바로': 1,
#  '밖에': 1,
#  '밖에서': 1,
#  '밖에서도': 1,
#  '밖이랑': 1,
#  '반드시': 1,
#  '반면에': 2,
#  '반에나': 2,
#  '반지하라': 1,
#  '반지하였습니다': 1,
#  '반쯤': 2,
#  '받아주셔서': 1,
#  '받았는데': 1,
#  '받았다': 1,
#  '받지': 1,
#  '발견': 1,
#  '발이': 1,
#  '밟으면': 1,
#  '밤까지': 1,
#  '밤마다': 1,
#  '밤에': 3,
#  '밥먹을': 1,
#  '방데우고': 1,
#  '방데워지는데': 1,
#  '방도': 1,
#  '방들보다': 1,
#  '방문하지': 1,
#  '방문했던': 1,
#  '방법만': 1,
#  '방법에는': 1,
#  '방법은': 1,
#  '방법을': 1,
#  '방에': 2,
#  '방에도': 1,
#  '방은': 1,
#  '방을': 2,
#  '방음은': 1,
#  '방음이': 2,
#  '방이': 3,
#  '방이었습니다': 1,
#  '방인데': 1,
#  '방청소함': 1,
#  '방크기도': 1,
#  '버스': 2,
#  '버스정류장과': 2,
#  '번호로': 1,
#  '벗겨지거나': 1,
#  '벽지도': 2,
#  '벽지에': 1,
#  '변경하십시오': 1,
#  '변경한다고': 1,
#  '변명과': 2,
#  '별로': 1,
#  '별로였고': 1,
#  '별로였습니다': 1,
#  '별로였지만': 1,
#  '별로입니다': 2,
#  '보고': 1,
#  '보내준': 3,
#  '보며': 2,
#  '보면': 1,
#  '보시는': 2,
#  '보시면': 4,
#  '보여서': 2,
#  '보이네요ㅠㅠ': 1,
#  '보일러': 1,
#  '보일러도': 1,
#  '보일러로': 1,
#  '보일러를': 2,
#  '보일러키니까': 1,
#  '보지': 1,
#  '본인이': 1,
#  '볼때마다': 1,
#  '부분은': 2,
#  '부분인거': 1,
#  '부분입니다': 1,
#  '부식됐어요': 2,
#  '부엌': 6,
#  '부엌은': 1,
#  '부족하고': 1,
#  '부족하실': 1,
#  '부족함': 1,
#  '분들': 1,
#  '분들에게': 2,
#  '분에': 1,
#  '분위기': 1,
#  '분위기는': 4,
#  '분이': 2,
#  '분한테는': 1,
#  '불구하고': 2,
#  '불량하고': 1,
#  '불만족스러운': 1,
#  '불안': 2,
#  '불안정해서': 1,
#  '불안합니다': 1,
#  '불안했고요': 1,
#  '불안했던것': 1,
#  '불완전합니다': 2,
#  '불친절합니다': 2,
#  '불쾌할': 1,
#  '불쾌함이': 1,
#  '불편없어요': 1,
#  '불편한점은': 1,
#  '불편했구요': 1,
#  '불편했습니다': 1,
#  '불편했어요': 2,
#  '불폈했어요': 1,
#  '불평하는': 1,
#  '불행했다': 1,
#  '붙어있는': 1,
#  '붙어있어': 1,
#  '비가': 1,
#  '비교적': 1,
#  '비꼼으로': 2,
#  '비밀': 1,
#  '비밀번호': 2,
#  '비밀번호가': 1,
#  '비위가': 2,
#  '비지': 1,
#  '비품이없어서': 1,
#  '비해': 3,
#  '비해서': 1,
#  '빔프로젝트있어서': 1,
#  '빠르게': 1,
#  '빠르구요': 2,
#  '빠른점은': 1,
#  '빠지기가': 1,
#  '빠지는데': 1,
#  '빨리': 1,
#  '빵빵해서': 1,
#  '빼두어': 2,
#  '뿐더러': 2,
#  '사다놨어요': 2,
#  '사람': 1,
#  '사람들이': 1,
#  '사실상': 1,
#  '사실을': 1,
#  '사용에': 1,
#  '사용은': 1,
#  '사용하기': 1,
#  '사용하려고했지만': 1,
#  '사용하여': 1,
#  '사용했던': 1,
#  '사이': 2,
#  '사이트를': 1,
#  '사이트에': 1,
#  '사전': 1,
#  '사전에': 2,
#  '사진과': 4,
#  '사진보다': 1,
#  '사진보다는': 1,
#  '사진빨이에요': 1,
#  '사진에서와': 2,
#  '사진으로': 1,
#  '사진이': 1,
#  '사진이랑': 4,
#  '사진처럼': 2,
#  '살고': 1,
#  '살짝': 2,
#  '샀다': 1,
#  '상기시켜줍니다': 1,
#  '상당히': 1,
#  '상쾌하지': 1,
#  '상태가': 4,
#  '상태도': 1,
#  '상태로': 1,
#  '상태를': 1,
#  '상태였고': 1,
#  '상태였습니다': 2,
#  '상황으로': 1,
#  '생각되네요': 1,
#  '생각보다': 1,
#  '생각하고': 1,
#  '생각합니다': 1,
#  '생각했습니다': 1,
#  '생겨도': 2,
#  '생활에는': 1,
#  '생활용품이': 2,
#  '샤워': 1,
#  '샤워는': 1,
#  '샤워를': 1,
#  '샤워를하기': 1,
#  '샤워하기': 1,
#  '샤워할때': 1,
#  '샴푸': 3,
#  '샴푸를': 2,
#  '샴푸린스바디클렌징폼': 1,
#  '서서': 1,
#  '서울의': 1,
#  '서초쪽': 1,
#  '선착순일': 2,
#  '세면대': 1,
#  '세면대에': 2,
#  '세입자가': 1,
#  '세입자를주지': 1,
#  '세제도': 2,
#  '세탁기는': 1,
#  '세탁기를': 2,
#  '세탁하고': 1,
#  '셀프로': 1,
#  '셌음': 1,
#  '셔츠를': 1,
#  '셔파에': 1,
#  '소개에': 1,
#  '소리도': 2,
#  '소리에': 1,
#  '소유자가': 3,
#  '소유자는': 1,
#  '소유자에게': 1,
#  '소음은': 1,
#  '소통간': 2,
#  '소통도': 2,
#  '소통은': 1,
#  '손님': 1,
#  '솔직히': 1,
#  '쇼파도': 1,
#  '수건': 3,
#  '수건도': 1,
#  '수건은': 4,
#  '수건이': 1,
#  '수도': 1,
#  '수도공사로': 1,
#  '수립을': 1,
#  '수압도': 2,
#  '수준을': 1,
#  '수집하는건지': 2,
#  '수화물을': 1,
#  '숙박예정인': 1,
#  '숙박하기엔': 1,
#  '숙소': 7,
#  '숙소건물과': 2,
#  '숙소는': 2,
#  '숙소들에': 1,
#  '숙소라고': 1,
#  '숙소로': 1,
#  '숙소를': 7,
#  '숙소에': 3,
#  '숙소였어요': 1,
#  '숙소위치가': 1,
#  '숙소의': 7,
#  '숙소입니다': 3,
#  '숙소주소는': 1,
#  '숙소주소랑': 1,
#  '숙소주소로': 1,
#  '숙소주소와': 1,
#  '숙주와': 1,
#  '쉬고': 1,
#  '쉽게': 2,
#  '쉽기는': 2,
#  '쉽다': 1,
#  '슈퍼랑': 1,
#  '스스로': 2,
#  '슬리퍼가': 1,
#  '시간보다': 1,
#  '시간으로부터': 1,
#  '시간은': 1,
#  '시간을': 2,
#  '시간이': 5,
#  '시경에': 1,
#  '시설': 1,
#  '시설상태가': 1,
#  '시설은': 1,
#  '시작이자': 1,
#  '시체가': 1,
#  '식기': 2,
#  '식기가': 2,
#  '신경써주셨으면': 2,
#  '신경이': 1,
#  '신논현역': 1,
#  '신논현역에서': 2,
#  '신중해질꺼같네요': 1,
#  '실망스럽고': 1,
#  '실망했다': 1,
#  '실제로': 1,
#  '심지어': 1,
#  '싱글이라서': 1,
#  '싶게': 1,
#  '싶어요': 1,
#  '싶지': 2,
#  '싶진않습니다': 2,
#  '써야하는게': 1,
#  '써져': 1,
#  '썼습니다': 1,
#  '쓰고': 2,
#  '쓰기': 2,
#  '쓰기에': 2,
#  '쓰라고': 2,
#  '쓰레기통도': 1,
#  '쓰실수': 1,
#  '쓰심': 1,
#  '쓰였습니다': 1,
#  '쓰지': 2,
#  '쓸모가': 1,
#  '씻기': 3,
#  '아니니': 2,
#  '아니라': 2,
#  '아니지만': 1,
#  '아닙니다': 1,
#  '아랫쪽에': 2,
#  '아무': 1,
#  '아쉬운': 2,
#  '아쉬운건': 2,
#  '아쉬운점은': 2,
#  '아쉬움이': 3,
#  '아쉬웠던': 2,
#  '아쉬웠던점은': 1,
#  '아쉬웠어요': 4,
#  '아쉽습니다': 1,
#  '아주': 2,
#  '악취가': 1,
#  '안나와서': 1,
#  '안내가': 2,
#  '안내도': 1,
#  '안내려가서': 2,
#  '안내를': 1,
#  '안돼서': 3,
#  '안되고': 1,
#  '안되는듯': 1,
#  '안된것이고': 1,
#  '안될뻔한것도': 1,
#  '안됩니다': 2,
#  '안들려서': 1,
#  '안락한': 1,
#  '안보였습니다': 1,
#  '안의': 1,
#  '안했지만': 1,
#  '앉아': 1,
#  '앉아먹기엔': 1,
#  '않고': 2,
#  '않기에': 2,
#  '않는': 3,
#  '않더라고요': 1,
#  '않습니다': 2,
#  '않아': 1,
#  '않아서': 3,
#  '않아요': 1,
#  '않았네요': 1,
#  '않았습니다': 3,
#  '않았어요': 2,
#  '않았으며': 1,
#  '않았음': 1,
#  '않았지만': 1,
#  '않으면': 1,
#  '않으시겠습니까': 1,
#  '않은': 4,
#  '않을': 1,
#  '않음': 2,
#  '알러지가': 1,
#  '알려달라': 1,
#  '알려드렸고': 1,
#  '알려주는': 2,
#  '알려주는게': 1,
#  '알려주신': 3,
#  '알려줘야합니다': 1,
#  '알리는': 1,
#  '알리십시오': 1,
#  '암호를': 2,
#  '앞뒤양옆으로': 2,
#  '약간': 1,
#  '약간의': 1,
#  '양호한': 1,
#  '어느': 1,
#  '어두워서': 4,
#  '어둡고': 3,
#  '어디인지': 2,
#  '어려우며': 1,
#  '어렵습니다': 2,
#  '언제': 2,
#  '언주역에서': 1,
#  '엄청': 1,
#  '없고': 3,
#  '없는': 1,
#  '없는게': 1,
#  '없다': 1,
#  '없다고': 2,
#  '없어서': 11,
#  '없었구요': 1,
#  '없었다': 1,
#  '없었던': 1,
#  '없었습니다': 5,
#  '없었으며': 1,
#  '없으니': 1,
#  '없으며': 1,
#  '없으면': 1,
#  '없음': 1,
#  '없이': 1,
#  '엉뚱한': 1,
#  '엉망입니다': 1,
#  '에그': 1,
#  '에어비앤비': 1,
#  '에어비앤비에': 2,
#  '에어비앤비에서': 1,
#  '에어비엔비의': 1,
#  '에어앤비의': 1,
#  '에어컨이': 2,
#  '엘레베이터가': 2,
#  '여기로': 1,
#  '여자끼리': 2,
#  '여행': 1,
#  '여행계획': 1,
#  '여행구성원간의': 1,
#  '여행을': 1,
#  '여행이': 1,
#  '여행이었습니다': 1,
#  '역시': 2,
#  '역에서': 2,
#  '역이랑': 1,
#  '연락': 1,
#  '연락도': 2,
#  '연락을': 1,
#  '연락이': 4,
#  '연락하면': 1,
#  '연락하였으나': 1,
#  '열릴수': 1,
#  '열어놓으셔서': 1,
#  '열자마자': 2,
#  '영하': 1,
#  '옆의': 1,
#  '옆집에서': 2,
#  '예쁘고': 1,
#  '예약고객도': 1,
#  '예약고객에게': 1,
#  '예약시': 2,
#  '예약을': 2,
#  '예약페이지에서': 1,
#  '예약한': 1,
#  '예약했지만': 1,
#  '예정된': 1,
#  '오기를': 1,
#  '오는': 4,
#  '오라고': 2,
#  '오래되었다는': 1,
#  '오래되었습니다': 1,
#  '오랜': 1,
#  '오전': 2,
#  '오지': 1,
#  '오피스텔이었구요': 1,
#  '오해가': 2,
#  '오후': 2,
#  '온돌로': 1,
#  '온수': 1,
#  '온수가': 1,
#  '온수공급이': 1,
#  '온수작동이': 1,
#  '온수잘나오고': 1,
#  '올라오지않을까': 1,
#  '옷을': 1,
#  '와서': 1,
#  '와야': 1,
#  '와이파이': 2,
#  '와이파이가': 1,
#  '와주셔서': 1,
#  '완벽해요': 2,
#  '완전히': 1,
#  '왔습니다': 3,
#  '왔어': 1,
#  '외국인들이': 1,
#  '외에': 1,
#  '외에는': 3,
#  '외출로': 1,
#  '요청해야한다고': 1,
#  '요청했었는데': 1,
#  '욕실': 1,
#  '욕실과': 2,
#  '욕실에서': 1,
#  '욕실은': 1,
#  '욕실의': 1,
#  '욕실이': 2,
#  '욕조가': 1,
#  '용도면에서는': 1,
#  '용이한': 2,
#  '우리': 2,
#  '우리가': 1,
#  '우리는': 10,
#  '우리에게는': 1,
#  '우리와': 1,
#  '우리일행은': 1,
#  '우선': 2,
#  '우선으로': 2,
#  '우유': 1,
#  '울렸습니다': 1,
#  ...}

# %% [markdown]
# ### 시각화

# %%
# 후기 안좋은 숙소
icon = Image.open(icon_path).convert("RGBA")
mask = Image.new("RGB", icon.size, (255,255,255))
mask.paste(icon,icon)
mask = np.array(mask)

wc = WordCloud(font_path=font_path, background_color="white", max_words=2000, mask=mask,
               max_font_size=300, random_state=42).generate_from_frequencies(tf_word_dict1)

plt.figure(figsize=(15, 45))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()
wc.to_file("AirBnb_review.png") # 그림파일로 추출하기
